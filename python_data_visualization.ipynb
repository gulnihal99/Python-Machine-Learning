# %% [markdown]
# # Python İle Veri Görselleştirme

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16], "r+")
plt.xlabel("Tam Sayılar")
plt.ylabel("Tam Sayıların Kareleri")
plt.title("Bazı Tam Sayıların Kareleri")
plt.show()

# %%
import numpy as np

t = np.arange(0.0, 5.0, 0.2)

plt.plot(t, t, "r--", t, t**2, "bs", t, t**3, "g^")
plt.show()

# %%
veri = {"a" : np.arange(50),
        "c" : np.random.randint(0, 50, 50),
        "d" : np.random.randn(50)}
veri["b"] = veri["a"] + (10 * np.random.randn(50))
veri["d"] = np.abs(veri["d"]) * 100

plt.scatter("a", "b", c = "c", s = "d", data = veri)
plt.xlabel("a sütunundaki veriler")
plt.ylabel("b sğtunundaki veriler")
plt.show()

# %%
isimler = ["Ahmet", "Mehmet", "Ayşe", "Fatma"]
degerler = [5, 25, 50, 100]

plt.figure(figsize=(9,3))

plt.subplot(131)
plt.bar(isimler,degerler)

plt.subplot(132)
plt.scatter(isimler,degerler)

plt.subplot(133)
plt.plot(isimler, degerler)

plt.suptitle("Birçok Farklı Grafik")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
t = np.arange(0.0, 5.0, 0.2)

plt.plot(t, t, "r-", linewidth = 2.0)
plt.show()

# %%
t = np.arange(0.0, 5.0, 0.1)
plt.plot(t, (np.exp(-t) * np.cos(2 * np.pi * t)), "k", t, (np.exp(-t) * np.cos(2 * np.pi * t)), "bo")
plt.axis([0, 10, -1, 1])
plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2 * np.pi * t)

# fonksiyonun tanımlanması
#def Uydurmasyonfonksiyonhesapla(girdi_1, girdi_2):
    #return cikti_1, cikti_2, cikti_3 

#tanımlı fonksiyonun çağırılması
#cikti_1, cikti_2, cikti_3 = Uydurmasyonfonksiyonhesapla(girdi1,girdi2)

t = np.arange(0.0, 5.0, 0.1)
plt.plot(t, f(t), "k", t, f(t), "bo")
plt.axis([0, 10, -1, 1])
plt.show()

# %%
mu1 = 100
sigma1 = 15
x = mu1 + (sigma1 * np.random.randn(10000))

mu2 = 110
sigma2 = 10
y = mu2 + (sigma2 * np.random.randn(10000))

n, bins, patches = plt.hist(x, 100, density = 1, facecolor = "b", alpha = 0.25)
n, bins, patches = plt.hist(y, 100, density = 1, facecolor = "g", alpha = 0.25)

plt.xlabel("Veriler")
plt.ylabel("Olasılıklar")
plt.title(r'Veriler Histogramı: $\mu_1=100,\ \mu_2=110$') # r yi koyma sebebi tırnak içinde yazdıklarının özel karakter olması
plt.annotate('Gauss Tepesinin Eğrisi', xy=(100, 0.04), xytext=(130, 0.045),
             arrowprops=dict(facecolor = 'black', shrink =0.1)) # oku yazma kodu 
plt.text(75, 0.025, r'$\mu_1=100,\ \sigma_1=15$')
plt.text(120, 0.035, r'$\mu_1=100,\ \sigma_2=10$')
plt.axis([40, 160, 0, 0.05])
plt.grid(True)
plt.show()

# %%
x = np.arange(0, 10, 0.01)
y = np.exp(x)

plt.figure()
plt.subplot(121)
plt.plot(x,y)
plt.yscale('linear')
plt.title('Lineer (Doğrusal)')
plt.grid(True)

plt.subplot(122)
plt.plot(x,y)
plt.yscale('log')
plt.title('Logaritmik')
plt.grid(True)
plt.show()

# %% [markdown]
# # Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
veri = pd.read_csv("olimpiyatlar_temizlenmis.csv")
veri.head()
# Out:
#                        isim cinsiyet   yas     boy   kilo           takım  \
# 0      Edgar Lindenau Aabye        M  34.0  182.48  95.62  Denmark/Sweden
# 1      Arvo Ossian Aaltonen        M  30.0  182.01  76.69         Finland
# 2      Arvo Ossian Aaltonen        M  30.0  177.00  75.00         Finland
# 3  Juhamatti Tapio Aaltonen        M  28.0  184.00  85.00         Finland
# 4   Paavo Johannes Aaltonen        M  28.0  175.00  64.00         Finland
#
#    uok   yil   sezon      sehir        spor  \
# 0  DEN  1900  Summer      Paris  Tug-Of-War
# 1  FIN  1920  Summer  Antwerpen    Swimming
# 2  FIN  1920  Summer  Antwerpen    Swimming
# 3  FIN  2014  Winter      Sochi  Ice Hockey
# 4  FIN  1948  Summer     London  Gymnastics
#
#                                  etkinlik madalya
# 0             Tug-Of-War Men's Tug-Of-War    Gold
# 1  Swimming Men's 200 metres Breaststroke  Bronze
# 2  Swimming Men's 400 metres Breaststroke  Bronze
# 3             Ice Hockey Men's Ice Hockey  Bronze
# 4  Gymnastics Men's Individual All-Around  Bronze

# %% [markdown]
# Saçılım Grafiği

# %%
def sacilimgrafikciz():
    sns.scatterplot(x = "boy", y = "kilo", data=veri)
    plt.title("Boy ve Ağırlık İlişkisi - Beyaz Izagara Tema")
    plt.show()
sacilimgrafikciz()

# %%
sns.set_style("white")
sacilimgrafikciz()

# %%
sns.set_style("darkgrid")
sacilimgrafikciz()

# %%
sns.set_style("whitegrid")
sacilimgrafikciz()

# %% [markdown]
# Saçılım Grafiği - Kategorik

# %%
sns.scatterplot(x = "boy", y = "kilo", hue = "madalya", data=veri)
plt.title("Madalyaya Göre Boy ve Ağırlık Dağılımı")
plt.show()

# %%
sns.set_style("whitegrid")
sns.scatterplot(x = "boy", y = "kilo", hue = "cinsiyet", data=veri)
plt.xlabel("Sporcuların Boyu")
plt.ylabel("Sporcuların Ağırlığı")
plt.title("Madalyaya Göre Boy ve Ağırlık Dağılımı")
plt.show()

# %%
sns.set_style("whitegrid")
sns.scatterplot(x = "boy", y = "kilo", hue = "cinsiyet", style = "madalya", size = "yas", sizes=(15, 200), data=veri)
plt.xlabel("Sporcuların Boyu")
plt.ylabel("Sporcuların Ağırlığı")
plt.title("Madalyaya Göre Boy ve Ağırlık Dağılımı")
plt.show()

# %%
sns.regplot(x = "boy", y = "kilo", data = veri, marker = "+", scatter_kws = {"alpha": 0.2})
plt.title("boy ve Kilo Ağırlıkları")
plt.show()

# %%
sns.scatterplot(x = "boy", y = "kilo", hue = "madalya", data=veri, palette = "Set1")
plt.title("Madalyaya Göre Boy ve Kilo Dağılımı")
plt.show()

# %%
sns.scatterplot(x = "boy", y = "kilo", hue = "madalya", data=veri, palette = "rocket")
plt.title("Madalyaya Göre Boy ve Kilo Dağılımı")
plt.show()

# %%
sns.lineplot(x = "boy", y = "kilo", data = veri)
plt.title("Boy ve Kilo")
plt.show()

# %%
sns.lineplot(x = "boy", y = "kilo", hue = "madalya", data = veri)
plt.title("Cinsiyete Göre Boy ve Kilo İlişkileri")
plt.show()

# %%
sns.lineplot(x = "boy", y = "kilo", hue = "sezon", data = veri)
plt.title("Cinsiyete Göre Boy ve Kilo İlişkileri")
plt.show()

# %% [markdown]
# # Histogram

# %%
sns.displot(veri, x = "kilo")
plt.ylabel("Frekans")
plt.title("Ağırlık Histogramı")
plt.show()

# %%
sns.displot(veri, x = "kilo", hue = "cinsiyet")
plt.ylabel("Frekans")
plt.title("Cinsiyete Göre Ayrıştırılmış Ağırlık Histogramı")
plt.show()

# %%
sns.displot(veri, x = "kilo", col = "cinsiyet", multiple = "dodge")
plt.show()

# %% [markdown]
# # İki Boyutlu Histogram

# %%
sns.displot(veri, x = "kilo", y = "boy", kind = "kde")
plt.xlabel("Ağırlık")
plt.ylabel("Boy")
plt.title("Ağırlık - Boy Histogramı")
plt.show()

# %%
sns.displot(veri, x = "kilo", y = "boy", hue= "cinsiyet", kind = "kde")
plt.xlabel("Ağırlık")
plt.ylabel("Boy")
plt.title("Cinsiyete Göre Ayrıştırılmış Ağırlık - Boy Histogramı")
plt.show()

# %%
sns.kdeplot(data = veri, x = "kilo", y = "boy", hue= "cinsiyet", fill = True)
plt.xlabel("Ağırlık")
plt.ylabel("Boy")
plt.title("Cinsiyete Göre Ayrıştırılmış Ağırlık - Boy Histogramı")
plt.show()

# %% [markdown]
# # Çizgi Grafiği

# %%
sns.barplot(x = "madalya", y = "boy", data = veri, hue = "cinsiyet")
plt.title("Madalyalara Göre Boy Grafikleri")
plt.show()

# %%
sns.catplot(x = "madalya", y = "yas", data = veri, hue = "cinsiyet", col = "sezon", kind = "bar", height = 4, aspect = 0.7)
plt.show()

# %% [markdown]
# # Kutu Grafiği

# %%
sns.boxplot(x = "sezon", y = "boy", hue = "cinsiyet", data = veri, palette = "Set2")
plt.show()

# %%
veri_gecici = veri.loc[:,["yas", "kilo", "boy"]]
sns.boxplot(data = veri_gecici, orient = "h", palette = "rocket")
plt.show()

# %%
sns.catplot(x = "sezon", y = "boy", data = veri, hue = "cinsiyet", col = "madalya", kind = "box", height = 4, aspect = 0.7)
plt.show()

# %% [markdown]
# # Isı Haritası

# %%
sns.heatmap(veri.corr(), annot = True, linewidths = 0.5, fmt = ".1f")
plt.show()

# %% [markdown]
# # Keman Grafiği

# %%
sns.violinplot(x = "sezon", y = "boy", data = veri)
plt.show()

# %%
sns.violinplot(x = "sezon", y = "boy", hue = "cinsiyet", data = veri)
plt.show()

# %%
sns.violinplot(x = "sezon", y = "boy", hue = "cinsiyet", data = veri, split = True)
plt.show()

# %%
sns.catplot(x = "sezon", y = "boy", data = veri, hue = "cinsiyet", col = "madalya", kind = "violin", split = True, height = 4, aspect = 0.7)
plt.show()

# %%
sns.jointplot(data = veri, x = "kilo", y = "boy", hue = "sezon", kind = "kde")
plt.show()

# %%
g = sns.JointGrid(data = veri, x= "kilo", y = "boy")
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)
plt.show()

# %% [markdown]
# # Çift / Eş Grafiği

# %%
sns.pairplot(veri)
plt.show()

# %%
g = sns.PairGrid(veri)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill = True)
g.map_diag(sns.histplot, fill = True)
plt.show()

# %%
sns.countplot(x = "sehir", data = veri)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Plotly

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings("ignore")

from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected = True)
import plotly.graph_objs as go
import plotly.io as pio
import plotly.figure_factory as ff
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
veri = pd.read_csv("universite_siralamasi.csv")
veri.head(3)
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# 0       20,152                  8.9                    25%               NaN
# 1        2,243                  6.9                    27%           33 : 67
# 2       11,074                  9.0                    33%           37 : 63
#
#    year
# 0  2011
# 1  2011
# 2  2011

# %%
veri.columns
# Out:
# Index(['world_rank', 'university_name', 'country', 'teaching', 'international',
#        'research', 'citations', 'income', 'total_score', 'num_students',
#        'student_staff_ratio', 'international_students', 'female_male_ratio',
#        'year'],
#       dtype='object')

# %%
veri.rename(columns = {"world_rank"               : "dunya_siralama",
                       "university_name"          : "uni_isim",
                       "country"                  : "ulke",
                       "teaching"                 : "ogretim",
                       "international"            : "uluslararasi",
                       "research"                 : "arastirma",
                       "citations"                : "alinti",
                       "income"                   : "gelir",
                       "total_score"              : "toplam_puan",
                       "num_students"             : "ogrenci_sayisi",
                       "student_staff_ratio"      : "ogrenci_calisan_orani",
                       "international_students"   : "uluslararasi_ogrenci",
                       "female_male_ration"       : "kadin_erkek_orani",
                       "year"                     : "yil"}, inplace = True)
veri.head(2)
# Out:
#   dunya_siralama                            uni_isim  \
# 0              1                  Harvard University
# 1              2  California Institute of Technology
#
#                        ulke  ogretim uluslararasi  arastirma  alinti gelir  \
# 0  United States of America     99.7         72.4       98.7    98.8  34.5
# 1  United States of America     97.7         54.6       98.0    99.9  83.7
#
#   toplam_puan ogrenci_sayisi  ogrenci_calisan_orani uluslararasi_ogrenci  \
# 0        96.1         20,152                    8.9                  25%
# 1        96.0          2,243                    6.9                  27%
#
#   female_male_ratio   yil
# 0               NaN  2011
# 1           33 : 67  2011

# %%
df = veri.iloc[:100,:]
df.head(3)
# Out:
#   dunya_siralama                               uni_isim  \
# 0              1                     Harvard University
# 1              2     California Institute of Technology
# 2              3  Massachusetts Institute of Technology
#
#                        ulke  ogretim uluslararasi  arastirma  alinti gelir  \
# 0  United States of America     99.7         72.4       98.7    98.8  34.5
# 1  United States of America     97.7         54.6       98.0    99.9  83.7
# 2  United States of America     97.8         82.3       91.4    99.9  87.5
#
#   toplam_puan ogrenci_sayisi  ogrenci_calisan_orani uluslararasi_ogrenci  \
# 0        96.1         20,152                    8.9                  25%
# 1        96.0          2,243                    6.9                  27%
# 2        95.6         11,074                    9.0                  33%
#
#   female_male_ratio   yil
# 0               NaN  2011
# 1           33 : 67  2011
# 2           37 : 63  2011

# %%
# plotly stilleri
pio.templates.default = "simple_white"

# %% [markdown]
# # Çizgi Grafiği

# %% [markdown]
# cizgi1 = go.Scatter(x = df.dunya_siralama,
#                     y = df.alinti,
#                     mode = "lines+markers",
#                     name = "Alıntı",
#                     marker = dict(color = "rgba(78, 78, 250, 0.85)"),
#                     text = df.uni_isim)
#
# cizgi2 = go.Scatter(x = df.dunya_siralama,
#                     y = df.ogretim,
#                     mode = "lines+markers",
#                     name = "Eğitim - Öğretim Faaliyetleri",
#                     marker = dict(color = "rgba(202, 43, 15, 0.85)"),
#                     text = df.uni_isim)
#
# veri = [cizgi1, cizgi2]
# yerlesim = dict(title = "Dünya Sıralamasında İlk 100 Üniversitenin Atıf ve Eğitim - Öğretim Puanları",
#                 xaxis = dict(title = "Dünya Sıralaması", ticklen = 5, zeroline = False))
# fig = dict(data = veri, layout = yerlesim)
# plot(fig, filename = "1-cizgi-alıntı ve ogretim puanları.html")

# %% [markdown]
# # Çubuk Grafiği

# %%
veri2014 = df[df.yil == 2011].iloc[:5,:]

cizgi1 = go.Bar(x = veri2014.uni_isim,
                    y = veri2014.alinti,
                    name = "Alıntı",
                    marker = dict(color = "rgba(255, 127, 40, 0.5)",
                             line = dict(color = "rgb(0,0,0)", width = 1.5)),
                    text = veri2014.ulke)

cizgi2 = go.Bar(x = veri2014.uni_isim,
                    y = veri2014.ogretim,
                    name = "Eğitim Öğretim Faaliyetleri",
                    marker = dict(color = "rgba(64, 10, 128, 0.5)",
                    line = dict(color = "rgb(0,0,0)", width = 1.5)),
                    text = veri2014.ulke)

veri_ = [cizgi1, cizgi2]
yerlesim = go.Layout(barmode = "group")
fig = go.Figure(data = veri_, layout = yerlesim)
plot(fig, filename = '2-cubuk-alıntı ve ogretim puanları.html')
# Out:
# '2-cubuk-alıntı ve ogretim puanları.html'

# %% [markdown]
# # Dairesel Grafik

# %%
veri2011 = df[df.yil == 2011].iloc[:8,:]
dilim1 = veri2011.ogrenci_sayisi
dilim1_liste = [float(each.replace(",", ".")) for each in veri2011.ogrenci_sayisi]
etiketler = veri2011.uni_isim

cizgi = go.Pie(labels = etiketler,
               values = dilim1_liste,
               hoverinfo = 'label+value+percent',
               textinfo = 'value+percent',
               textfont = dict(size = 8),
               rotation = 180,
               hole = 0.3,
               marker = dict(line = dict(color = '#000000', width = 1)))

veri_ = [cizgi]
yerlesim = dict(title = "2011 Yılı İlk 8 Üniversitenin Öğrenci Sayıları ve Oranları",
                legend = dict(orientation = "h"))
fig = dict(data = veri_, layout = yerlesim)
plot(fig, filename = '3-dairesel-ogrenci-sayisi.html')
# Out:
# '3-dairesel-ogrenci-sayisi.html'

# %% [markdown]
# # Kabarcık Grafiği

# %%
veri2011 = df[df.yil == 2011].iloc[:20,:]
ogrenci_sayisi = [float(each.replace(",", ".")) for each in veri2011.ogrenci_sayisi]
uluslararasi_renk = [float(each) for each in veri2011.uluslararasi]

data = [{'y' : veri2011.ogretim,
         'x' : veri2011.dunya_siralama,
         'mode' : 'markers',
         'markers' : {'color' : uluslararasi_renk,
                      'size' : ogrenci_sayisi,
                      'showscale' : True},
         'text' : veri2011.uni_isim}]
plot(data, filename = '4-kabarcik-ogrenci-sayisi.html')
# Out:
#   Input In [75]
#     uluslararasi_renk = for each in veri2011.uluslararasi
#                         ^
# SyntaxError: invalid syntax
